# %%
# %sql
CREATE TABLE IF NOT EXISTS dataquality.dq_demo.ingest_state (
  pipeline_name STRING,
  last_processed_hour TIMESTAMP,
  updated_at TIMESTAMP
)
USING DELTA;

# %%
# %sql
INSERT INTO dataquality.dq_demo.ingest_state
VALUES (
  'bev_hourly_pipeline',
  TIMESTAMP '2026-01-01 00:00:00',
  current_timestamp()
);
